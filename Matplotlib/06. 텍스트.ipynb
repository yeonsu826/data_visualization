# %% [markdown]
# # 6. 텍스트

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y) #각 데이터의 정확한 수치를 알고 싶을 때

# %%
plt.plot(x,y,marker='o')
plt.text(x[idx], y[idx]+0.2, txt, ha='center' ,color='red')
# Out:
# Text(3, 8.2, '8')

# %%
for idx, txt in enumerate(y):
    print(idx,txt)
    # y 값 (리스트)의 index와 값을 출력함

print(" ")
for idx, txt in enumerate(x):
    print(idx,txt)
    # x 값 (리스트)의 index와 값을 출력함


print(" ")
for idx,txt in enumerate(y):
    print(x[idx],y[idx])
    # x 값, y 값 출력
# Out:
# 0 2
# 1 4
# 2 8
#
# 0 1
# 1 2
# 2 3
#
# 1 2
# 2 4
# 3 8

# %%
plt.plot(x,y,marker='o')

for idx, txt in enumerate(y):
    plt.text(x[idx], y[idx]+0.2, txt, ha='center' ,color='red')
    # x[idx] 는 그래프의 데이터 x위치 y[idx]는 그래프의 데이터 y위치이다.
    # txt 는 y 값을 가져온다.
    # ha = 'center' 수평정렬 중심으로

# %%
# Out:
# 0 2
# 1 4
# 2 8

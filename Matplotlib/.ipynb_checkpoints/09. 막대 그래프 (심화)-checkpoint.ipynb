# %% [markdown]
# # 9. 막대 그래프 (심화)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

x=[1,2,3]
y=[2,4,8]

# %%
# 옆으로 늘어나는 막대 그래프

labels = ['강백호','서태웅','정대만'] #이름
values = [190,187,184] #키

plt.barh(labels,values, height=0.3)
# bar뒤에 h 만 붙이면 됨
# 그래프 크기 줄이려면 height로 입력
plt.xlim(175,195)
# Out:
# (175.0, 195.0)

# %%
# 그래프 이미지 패턴 넣기

bar = plt.bar(labels,values)
bar[0].set_hatch('/')
bar[1].set_hatch('+')
bar[2].set_hatch('*')

# %% [markdown]
# ## hatch 패턴
#
# https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html

# %%
# 글자 넣기 

bar = plt.bar(labels, values)
plt.ylim(175,195)
 
for idx,rect in enumerate(bar): # 
    plt.text(idx, rect.get_height()+0.5,values[idx], ha='center',color='b')

# %%
for idx,rect in enumerate(bar):
    print(idx,rect)
    # bar의 크기를 알려줌 

bar = plt.bar(x, y)

bar[0].set_angle(35)  # bar[0] 의 각도를 45도로 설정

#for rect in bar:
#    rect.set_angle(35)  # bar모두 각도를 45도로 설정
# Out:
# 0 Rectangle(xy=(0.6, 0), width=0.8, height=2, angle=35)
# 1 Rectangle(xy=(1.6, 0), width=0.8, height=4, angle=0)
# 2 Rectangle(xy=(2.6, 0), width=0.8, height=8, angle=0)
